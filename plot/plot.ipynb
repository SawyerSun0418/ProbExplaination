# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

for size in [10,20,30]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\NN\{}\experiment_plot_NN.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\NN\{}\experiment_original_ins_NN.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\NN\{}\experiment_sdp_NN.csv".format(size)
    ex_filename = r"..\experiments\MNIST\NN\{}\experiment_exp_NN.csv".format(size)
    reg_filename = r"..\regenerate_NN_{}.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (20,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    #nfslider.on_changed(slider_update)

        plt.show()
# Out:
# 10
# 20
# 30

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

for size in [10,20,30]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\LR\{}\experiment_plot_LR.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\LR\{}\experiment_original_ins_LR.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\LR\{}\experiment_sdp_LR.csv".format(size)
    ex_filename = r"..\experiments\MNIST\LR\{}\experiment_exp_LR.csv".format(size)
    reg_filename = r"..\regenerate_LR_{}.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (20,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    #nfslider.on_changed(slider_update)

        plt.show()
# Out:
# 10
# 20
# 30

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

exp_filename = "selected_X.csv"
ori_filename = "original_X.csv"
    #sdp_filename = r"..\experiments\MNIST\LR\{}\experiment_sdp_LR.csv".format(size)
    #ex_filename = r"..\experiments\MNIST\LR\{}\experiment_exp_LR.csv".format(size)

exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    #sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    #exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0]-1
finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
    fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
for i in range(1,finit+1):
    fig, ax = plt.subplots(figsize = (10,5), ncols=2)
    plt.subplots_adjust(bottom=0.15)
    ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        #title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        #title1.set_size(20)
    img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        #img = ax[2].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        #img = ax[3].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        #title2 = ax[2].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        #title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    #nfslider.on_changed(slider_update)

    plt.show()

# %%
#top 10 weight for active pixels


import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

for size in [10]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\weights_pred\{}\experiment_plot_1.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\weights_pred\{}\experiment_original_ins_1.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\weights_pred\{}\experiment_sdp_1.csv".format(size)
    ex_filename = r"..\experiments\MNIST\weights_pred\{}\experiment_exp_1.csv".format(size)
    reg_filename = r"..\experiments\MNIST\weights_pred\{}\experiment_sampled_1.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (30,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[2])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[i*9-ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[2].axis('off')
        #img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[5])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[9*(finit-i)+1+ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[5].axis('off')
        #img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)

    #nfslider.on_changed(slider_update)
        if i == 1:
            fig.suptitle("top active weights", fontsize=25)
        plt.show()
# Out:
# 10

# %%
#history of a normal run
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

filename = r"..\experiments\MNIST\history\30\history_instance_2.csv"
exp_name = r"..\experiments\MNIST\history\30\exp_history_instance_2.csv"
sdp_name = r"..\experiments\MNIST\history\30\sdp_history_instance_2.csv"

exps = np.genfromtxt(filename, delimiter=',', filling_values=0.5, skip_header=0)
exps_exp = np.genfromtxt(exp_name, delimiter=',', filling_values=0.5, skip_header=0)
exps_sdp = np.genfromtxt(sdp_name, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0] - 1
finit = n

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28, 28))

    fig.canvas.draw_idle()

for i in range(1, finit + 1, 3):
    fig, axes = plt.subplots(figsize=(15, 5), ncols=3)
    plt.subplots_adjust(bottom=0.15)

    for j in range(3):
        if i + j <= finit:
            img = axes[j].imshow(exps[i + j].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            title = axes[j].set_title("SDP: %f, EXP: %f" % (exps_sdp[i+j], exps_exp[i+j]))
    if i == 1:
        fig.suptitle("History of normal LR beam search", fontsize=16)

    plt.show()

# %%
#bad classifier

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys
from matplotlib import gridspec

for size in [20]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\bad\{}\experiment_plot_bad.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\bad\{}\experiment_original_ins_bad.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\bad\{}\experiment_sdp_bad.csv".format(size)
    ex_filename = r"..\experiments\MNIST\bad\{}\experiment_exp_bad.csv".format(size)
    reg_filename = r"..\experiments\MNIST\bad\{}\experiment_sampled_bad.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (30,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[2])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[i*9-ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[2].axis('off')
        #img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[5])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[9*(finit-i)+1+ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[5].axis('off')
        #img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)

    #nfslider.on_changed(slider_update)
        if i == 1:
            fig.suptitle("bad LR with acc 0.49", fontsize=25)
        plt.show()
# Out:
# 20

# %%
#topright classifier

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys
from matplotlib import gridspec

for size in [20]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\topright\{}\experiment_plot_topright.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\topright\{}\experiment_original_ins_topright.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\topright\{}\experiment_sdp_topright.csv".format(size)
    ex_filename = r"..\experiments\MNIST\topright\{}\experiment_exp_topright.csv".format(size)
    reg_filename = r"..\experiments\MNIST\topright\{}\experiment_sampled_topright.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (30,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[2])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[i*9-ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[2].axis('off')
        #img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[5])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[9*(finit-i)+1+ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[5].axis('off')
        #img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)

    #nfslider.on_changed(slider_update)
        if i == 1:
            fig.suptitle("Topright LR with acc 0.61, left side: correct classification   right side: incorrect classification", fontsize=25)
        plt.show()
# Out:
# 20

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

filename = r"..\experiments\MNIST\topright\20\history_instance_2.csv"
exp_name = r"..\experiments\MNIST\topright\20\exp_history_instance_2.csv"
sdp_name = r"..\experiments\MNIST\topright\20\sdp_history_instance_2.csv"

exps = np.genfromtxt(filename, delimiter=',', filling_values=0.5, skip_header=0)
exps_exp = np.genfromtxt(exp_name, delimiter=',', filling_values=0.5, skip_header=0)
exps_sdp = np.genfromtxt(sdp_name, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0] - 1
finit = n

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28, 28))

    fig.canvas.draw_idle()

for i in range(1, finit + 1, 3):
    fig, axes = plt.subplots(figsize=(15, 5), ncols=3)
    plt.subplots_adjust(bottom=0.15)

    for j in range(3):
        if i + j <= finit:
            img = axes[j].imshow(exps[i + j].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            title = axes[j].set_title("SDP: %f, EXP: %f" % (exps_sdp[i+j], exps_exp[i+j]))
    if i == 1:
        fig.suptitle("History of Topright LR beam search", fontsize=16)

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys
from matplotlib import gridspec

for size in [20]:
    print(size)
    print('\n')
    exp_filename = r"..\experiments\MNIST\normal\{}\experiment_plot_n.csv" .format(size)
    ori_filename = r"..\experiments\MNIST\normal\{}\experiment_original_ins_n.csv".format(size)
    sdp_filename = r"..\experiments\MNIST\normal\{}\experiment_sdp_n.csv".format(size)
    ex_filename = r"..\experiments\MNIST\normal\{}\experiment_exp_n.csv".format(size)
    reg_filename = r"..\experiments\MNIST\normal\{}\experiment_sampled_n.csv".format(size)

    exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    sdps = np.genfromtxt(sdp_filename, delimiter=',', filling_values=0.5, skip_header=0)
    exs = np.genfromtxt(ex_filename, delimiter=',', filling_values=0.5, skip_header=0)
    reg = np.genfromtxt(reg_filename, delimiter=',', filling_values=0.5, skip_header=0)
    n = exps.shape[0]-1
    finit = n

    def slider_update(val):
        img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
        fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
    original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
    for i in range(1,finit//2+1):
        fig, ax = plt.subplots(figsize = (30,5), ncols=6)
        plt.subplots_adjust(bottom=0.15)
        ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title1 = ax[0].set_title("SDP: %f, EXP: %f" % (sdps[i], exs[i]))
        title1.set_size(20)
        img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[2])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[i*9-ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[2].axis('off')
        #img = ax[2].imshow(reg[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[3].imshow(original[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        img = ax[4].imshow(exps[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        gs = gridspec.GridSpecFromSubplotSpec(3, 3, subplot_spec=ax[5])
        for ii in range(9):
            sub_ax = plt.Subplot(fig, gs[ii])
            fig.add_subplot(sub_ax)
            img = sub_ax.imshow(reg[9*(finit-i)+1+ii].reshape(28, 28), cmap='gray', vmin=0, vmax=1)
            sub_ax.axis('off')
            sub_ax.set_aspect('auto')
        ax[5].axis('off')
        #img = ax[5].imshow(reg[finit+1-i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
        title2 = ax[3].set_title("SDP: %f, EXP: %f" % (sdps[finit+1-i], exs[finit+1-i]))
        title2.set_size(20)
    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)

    #nfslider.on_changed(slider_update)
        if i == 1:
            fig.suptitle("Normal LR with acc 0.98, left side: correct classification   right side: incorrect classification", fontsize=25)
        plt.show()
# Out:
# 20
