# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

exp_filename = "LR\experiment_plot.csv"    
ori_filename = "LR\experiment_original_ins.csv"
#prb_filename = dirname + "probs.csv"

exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0]-1
finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
    fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
for i in range(1,finit+1):
    fig, ax = plt.subplots(ncols=2)
    plt.subplots_adjust(bottom=0.15)
    ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[0].set_title("Actual label: %d, Exp pred: %f" % (int(probs[0]), probs[1]))
    img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[1].set_title("Exp pred: %f" % (probs[finit+1]))

    nfax = plt.axes([0.2,0.05,0.65,0.03])
    nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    nfslider.on_changed(slider_update)

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

exp_filename = "LR\experiment_plot_100.csv"    
ori_filename = "LR\experiment_original_ins_100.csv"
#prb_filename = dirname + "probs.csv"

exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0]-1
finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
    fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
for i in range(1,finit+1):
    fig, ax = plt.subplots(ncols=2)
    plt.subplots_adjust(bottom=0.15)
    ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[0].set_title("Actual label: %d, Exp pred: %f" % (int(probs[0]), probs[1]))
    img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[1].set_title("Exp pred: %f" % (probs[finit+1]))

    nfax = plt.axes([0.2,0.05,0.65,0.03])
    nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    nfslider.on_changed(slider_update)

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

exp_filename = "NN\experiment_plot_100.csv"    
ori_filename = "NN\experiment_original_ins_100.csv"
#prb_filename = dirname + "probs.csv"

exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0]-1
finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
    fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
for i in range(1,finit+1):
    fig, ax = plt.subplots(ncols=2)
    plt.subplots_adjust(bottom=0.15)
    ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[0].set_title("Actual label: %d, Exp pred: %f" % (int(probs[0]), probs[1]))
    img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[1].set_title("Exp pred: %f" % (probs[finit+1]))

    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    nfslider.on_changed(slider_update)

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import sys

exp_filename = "experiment_plot.csv"    
ori_filename = "experiment_original_ins.csv"
#prb_filename = dirname + "probs.csv"

exps = np.genfromtxt(exp_filename, delimiter=',', filling_values=0.5, skip_header=0)
n = exps.shape[0]-1
finit = n
#probs = np.genfromtxt(prb_filename, delimiter=',', skip_header=0)
#if len(probs.shape) == 2:
#    probs = probs[:,0]

def slider_update(val):
    img.set_data(exps[int(val)].reshape(28,28))
#    ax[1].set_title("Exp pred: %f" % (probs[int(val+1)]))
    fig.canvas.draw_idle()

#instance corresponding to instance doing beam search on
original=np.genfromtxt(ori_filename, delimiter=',', filling_values=0.5, skip_header=0)
#original=np.array(original)
for i in range(1,finit+1):
    fig, ax = plt.subplots(ncols=2)
    plt.subplots_adjust(bottom=0.15)
    ax[0].imshow(original[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[0].set_title("Actual label: %d, Exp pred: %f" % (int(probs[0]), probs[1]))
    img = ax[1].imshow(exps[i].reshape(28,28), cmap='gray', vmin=0, vmax=1)
    #ax[1].set_title("Exp pred: %f" % (probs[finit+1]))

    #nfax = plt.axes([0.2,0.05,0.65,0.03])
    #nfslider = Slider(nfax, 'num features', valmin=1, valmax=n, valinit=finit, valstep=1)



    nfslider.on_changed(slider_update)

    plt.show()
